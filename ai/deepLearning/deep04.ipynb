# %%
import os
import numpy as np
import gdown
from pathlib import Path

import tensorflow as tf
from tensorflow import keras

# %%
url_path_map = {
        'train': {
            'url':'https://drive.google.com/uc?id=1JewlmOsqs-O1EmMMKutcYYiD7GkN6brN', 
            'path':'dataset/train.npy'
            },
        'test': {
            'url':'https://drive.google.com/uc?id=1JcCFZbc_N7VIa3G3XA8grwz4XGdaaXSZ', 
            'path':'dataset/test.npy'
            },
        'label': {
            'url':'https://drive.google.com/uc?id=1JiaTOcZ6QfDThw3RrIa3ZxDDaNt-BMUQ',
            'path':'dataset/label_info.txt'
        }
    }

# %%
def download_dataset():
    Path('dataset').mkdir(exist_ok=True)
    for split in ['train', 'test', 'label']:
        if Path(url_path_map[split]['path']).exists():
            continue
        gdown.download(url_path_map[split]['url'], url_path_map[split]['path'], quiet=False)

# %%
download_dataset()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JewlmOsqs-O1EmMMKutcYYiD7GkN6brN
# To: /content/dataset/train.npy
# 753MB [00:03, 245MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1JcCFZbc_N7VIa3G3XA8grwz4XGdaaXSZ
# To: /content/dataset/test.npy
# 753MB [00:03, 190MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1JiaTOcZ6QfDThw3RrIa3ZxDDaNt-BMUQ
# To: /content/dataset/label_info.txt
# 100%|██████████| 534/534 [00:00<00:00, 264kB/s]

# %%
def read_txt(file_name):
    with open(file_name, 'rt') as f:
        class_list = [row.strip('\n') for row in f.readlines()]
    return class_list

# %%
train_dir = '/content/dataset/train.npy'
test_dir = '/content/dataset/test.npy'
label_dir = '/content/dataset/label_info.txt'

# %%
train = np.load(train_dir, allow_pickle=True).item()
test = np.load(test_dir, allow_pickle=True).item()

# %%
train_image , train_label = train['image'], train['label']
test_image, test_label = test['image'], test['label']

# %%
train_image.shape, train_label.shape
# Out:
# ((500, 224, 224, 30), (500,))

# %%
test_image.shape, test_label.shape
# Out:
# ((500, 224, 224, 30), (500,))

# %%
train_image = np.split(train_image, 10, axis=3)
test_image = np.split(test_image, 10, axis=3)

# %%
train_image = np.array(train_image)
test_image = np.array(test_image)

# %%
train_image.shape, test_image.shape
# Out:
# ((10, 500, 224, 224, 3), (10, 500, 224, 224, 3))

# %%
train_image = train_image.reshape((-1, 224, 224, 3))
test_image = test_image.reshape((-1, 224, 224, 3))

# %%
train_image.shape, test_image.shape
# Out:
# ((5000, 224, 224, 3), (5000, 224, 224, 3))

# %%
label_temp = np.append(train_label, train_label) #2
label_temp = np.append(label_temp, label_temp) #4
label_temp = np.append(label_temp, label_temp) #8
label_temp = np.append(label_temp, train_label) #9
train_label_extended = np.append(label_temp, train_label) #10

# %%
test_label_extended = np.zeros(shape=(5000,))

# %%
train_label_extended.shape
# Out:
# (5000,)

# %%
train_image = train_image.astype('float32') / 255.0
test_image = test_image.astype('float32') / 255.0

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_image, train_label_extended))
test_dataset = tf.data.Dataset.from_tensor_slices((test_image, test_label_extended))

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 128

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)

# %%
import matplotlib.pyplot as plt
'''
#plt.figure(figsize=(3, 10))
for i in range(30):
  plt.subplot(3, 10, i+1)
  plt.imshow(train_image[i])
  '''
# Out:
# '\n#plt.figure(figsize=(3, 10))\nfor i in range(30):\n  plt.subplot(3, 10, i+1)\n  plt.imshow(train_image[i])\n  '

# %%
#plt.imshow(train_image[54])

# %%
label_list = read_txt(label_dir)

# %%
label_list
# Out:
# ['Bergamot',
#  'BlanketFlower',
#  'BleedingHeart',
#  'Bletilla',
#  'Bluebonnets',
#  'BluestarFlower',
#  'Brassica',
#  'Broom',
#  'Calceolaria',
#  'Celosia',
#  'Chionodoxa',
#  'CoralBells',
#  'CuckooFlower',
#  'Dietes',
#  'DutchIris',
#  'EnglishBluebell',
#  'Eremurus',
#  'FrangipaniFlower',
#  'Fuchsia',
#  'Guzmania',
#  'Hebe',
#  'Helenium',
#  'Hellebore',
#  'Honeysuckle',
#  'Ixia',
#  'Jacob’sLadder',
#  'KangarooPaw',
#  'Knautia',
#  'Lewesia',
#  'Lotus',
#  'Meconopsis',
#  'Mimosa',
#  'MorningGlory',
#  'NewZealandTeaTree',
#  'OrientalLily',
#  'Oxalis',
#  'OysterPlant',
#  'Pansy',
#  'Photinia',
#  'PincushionFlower',
#  'Poinsettia',
#  'Queen’sCup',
#  'RockRose',
#  'Scaevola',
#  'ScentedGeranium',
#  'Statice',
#  'Tuberose',
#  'UrnPlant',
#  'VirginiaCreeper',
#  'Winterberry']

# %%
from tensorflow.keras import models, layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D

# %%
model = models.Sequential()

# %%
# 1st Conv2d
#  - filter_cnt : 32 - kerner_size : (3,3) - relu
model.add(layers.Conv2D(filters=32, kernel_size=3, activation='relu',
                        input_shape=(224, 224, 3),
                        name='block_1_conv'))
# 1st max pooling
# - pool_size = (2,2)
model.add(layers.MaxPool2D(pool_size=2,name='block_1_pool'))
# 2nd Conv2d
#  - filter_cnt : 64 - kerner_size : (3,3) - relu
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='relu',
                        name='block_2_conv'))
# 2nd max pooling
# - pool_size = (2,2)
model.add(layers.MaxPool2D(pool_size=2, name='block_2_pool'))
# 3rd Conv2d
#  - filter_cnt : 64 - kerner_size : (3,3) - relu
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='relu',
                        name='block_3_conv'))
# Flatten
model.add(layers.Flatten())

#classification module
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=50, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block_1_conv (Conv2D)        (None, 222, 222, 32)      896
# _________________________________________________________________
# block_1_pool (MaxPooling2D)  (None, 111, 111, 32)      0
# _________________________________________________________________
# block_2_conv (Conv2D)        (None, 109, 109, 64)      18496
# _________________________________________________________________
# block_2_pool (MaxPooling2D)  (None, 54, 54, 64)        0
# _________________________________________________________________
# block_3_conv (Conv2D)        (None, 52, 52, 64)        36928
# _________________________________________________________________
# flatten (Flatten)            (None, 173056)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                11075648
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                3250
# =================================================================
# Total params: 11,135,218
# Trainable params: 11,135,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(train_dataset, epochs=50)
# Out:
# Epoch 1/50
# 79/79 [==============================] - 22s 58ms/step - loss: 3.9610 - accuracy: 0.0350
# Epoch 2/50
# 79/79 [==============================] - 5s 57ms/step - loss: 3.7681 - accuracy: 0.0510
# Epoch 3/50
# 79/79 [==============================] - 5s 57ms/step - loss: 3.6587 - accuracy: 0.0836
# Epoch 4/50
# 79/79 [==============================] - 5s 57ms/step - loss: 3.4854 - accuracy: 0.1402
# Epoch 5/50
# 79/79 [==============================] - 5s 57ms/step - loss: 3.0320 - accuracy: 0.2462
# Epoch 6/50
# 79/79 [==============================] - 5s 57ms/step - loss: 2.4267 - accuracy: 0.4090
# Epoch 7/50
# 79/79 [==============================] - 5s 57ms/step - loss: 1.9632 - accuracy: 0.5328
# Epoch 8/50
# 79/79 [==============================] - 5s 57ms/step - loss: 1.6577 - accuracy: 0.6220
# Epoch 9/50
# 79/79 [==============================] - 4s 57ms/step - loss: 1.3943 - accuracy: 0.6802
# Epoch 10/50
# 79/79 [==============================] - 5s 57ms/step - loss: 1.2718 - accuracy: 0.7128
# Epoch 11/50
# 79/79 [==============================] - 4s 57ms/step - loss: 1.0668 - accuracy: 0.7586
# Epoch 12/50
# 79/79 [==============================] - 4s 57ms/step - loss: 1.0201 - accuracy: 0.7782
# Epoch 13/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.9044 - accuracy: 0.8074
# Epoch 14/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.9161 - accuracy: 0.8050
# Epoch 15/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.8200 - accuracy: 0.8220
# Epoch 16/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.9830 - accuracy: 0.8058
# Epoch 17/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.8366 - accuracy: 0.8140
# Epoch 18/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.7585 - accuracy: 0.8356
# Epoch 19/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.6845 - accuracy: 0.8444
# Epoch 20/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.6519 - accuracy: 0.8496
# Epoch 21/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.6212 - accuracy: 0.8584
# Epoch 22/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.5470 - accuracy: 0.8694
# Epoch 23/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.5739 - accuracy: 0.8568
# Epoch 24/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.5507 - accuracy: 0.8616
# Epoch 25/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.5548 - accuracy: 0.8618
# Epoch 26/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.5422 - accuracy: 0.8620
# Epoch 27/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.5911 - accuracy: 0.8602
# Epoch 28/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.6041 - accuracy: 0.8532
# Epoch 29/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.5661 - accuracy: 0.8566
# Epoch 30/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.6040 - accuracy: 0.8454
# Epoch 31/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.5323 - accuracy: 0.8444
# Epoch 32/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.4768 - accuracy: 0.8400
# Epoch 33/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.4523 - accuracy: 0.8352
# Epoch 34/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.4414 - accuracy: 0.8334
# Epoch 35/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.4124 - accuracy: 0.8330
# Epoch 36/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3816 - accuracy: 0.8332
# Epoch 37/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3798 - accuracy: 0.8296
# Epoch 38/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.3820 - accuracy: 0.8260
# Epoch 39/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3551 - accuracy: 0.8274
# Epoch 40/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3449 - accuracy: 0.8254
# Epoch 41/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3356 - accuracy: 0.8246
# Epoch 42/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.3382 - accuracy: 0.8218
# Epoch 43/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3270 - accuracy: 0.8226
# Epoch 44/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3290 - accuracy: 0.8268
# Epoch 45/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3188 - accuracy: 0.8326
# Epoch 46/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3277 - accuracy: 0.8278
# Epoch 47/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3299 - accuracy: 0.8250
# Epoch 48/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3222 - accuracy: 0.8274
# Epoch 49/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.3139 - accuracy: 0.8260
# Epoch 50/50
# 79/79 [==============================] - 4s 57ms/step - loss: 0.3253 - accuracy: 0.8294

# %%
loss, accuracy = model.evaluate(train_dataset)
# Out:
# 79/79 [==============================] - 5s 31ms/step - loss: 0.2300 - accuracy: 0.8918

# %%
predictions = model.predict(test_image)

# %%
np.argmax(predictions[2])
# Out:
# 19

# %%
import pandas as pd

# %%
id=[]
pred=[]
for i in range(500):
  id.append(i)
  pred.append(np.argmax(predictions[i]))

# %%
challenge = pd.DataFrame({'image_id':id, 'label':pred})

# %%
challenge
# Out:
#      image_id  label
# 0           0     27
# 1           1     25
# 2           2     19
# 3           3     27
# 4           4     39
# ..        ...    ...
# 495       495      6
# 496       496     42
# 497       497     23
# 498       498     12
# 499       499      9
#
# [500 rows x 2 columns]

# %%
challenge.to_csv('deepChallenge04.csv', index=False)
